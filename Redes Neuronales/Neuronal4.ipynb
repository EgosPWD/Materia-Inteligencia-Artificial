# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

import seaborn as sns
titanic = sns.load_dataset("titanic")

data = titanic[['pclass','sex','age','sibsp','parch','fare','embarked','survived']].dropna()

data['sex'] = data['sex'].map({'male':0, 'female':1})
data['embarked'] = data['embarked'].map({'C':0, 'Q':1, 'S':2})

X = data.drop('survived', axis=1)
y = data['survived']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

mlp = MLPClassifier(hidden_layer_sizes=(10,10), activation='relu', max_iter=1000)
mlp.fit(X_train, y_train)

y_pred = mlp.predict(X_test)
print("Precisión en test:", accuracy_score(y_test, y_pred))
# Out:
# Precisión en test: 0.7757009345794392
