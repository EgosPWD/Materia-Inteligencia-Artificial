# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.impute import SimpleImputer # Import SimpleImputer

from tensorflow.keras import layers, models, callbacks
from sklearn.pipeline import Pipeline

# %%
SEED = 43
os.environ["PYTHONHASHSEED"] = str(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
URL = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(URL)

# %%
print("Shape bruto: ", df.shape)
print("Cols: ", list(df.columns))
# Out:
# Shape bruto:  (891, 12)
# Cols:  ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
y = df["Survived"].astype(int).values

# %%
X = df[["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]].copy()

# %%
X["FamilySize"] = X["SibSp"].fillna(0) + X["Parch"].fillna(0) + 1
X["IsAlone"] = (X["FamilySize"] == 1).astype(int)

# %%
num_cols = ["Age", "SibSp", "Parch", "Fare", "FamilySize"]
cat_cols = ["Pclass", "Sex", "Embarked"]

# %%
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy= "median")),
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy= "most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
]
)

# %%
from sklearn.pipeline import Pipeline
preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, num_cols),
        ("cat", categorical_transformer, cat_cols)
    ], remainder = "drop"
)

# %%
X_train_df, X_test_df, y_train, y_test = train_test_split(
    X,y, test_size=0.2, random_state=SEED, stratify=y
)

# %%
X_train = preprocess.fit_transform(X_train_df)
X_test = preprocess.transform(X_test_df)

X_train = X_train.astype("float32")
X_test = X_test.astype("float32")

# %%
def build_model(input_dim: int) -> tf.keras.Model:
    model = models.Sequential(
        [layers.Input(shape=(input_dim,)),
        layers.Dense(32, activation="relu"),
        layers.Dropout(0.15),
        layers.Dense(32, activation="relu"),
        layers.Dropout(0.15),
        layers.Dense(1, activation="sigmoid")

         ]

    )
    model.compile(
        optimizer="adam",
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model


model = build_model(X_train.shape[1])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,537 (6.00 KB)
#  Trainable params: 1,537 (6.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cbs = [
    callbacks.EarlyStopping(monitor="val_auc", mode="max", patience=12, restore_best_weights=True),
    callbacks.ModelCheckpoint("titanic_best_keras.keras", monitor="val_auc", mode="max", save_best_only=True),
    callbacks.ReduceLROnPlateau(monitor="val_loaa", factor=0.5, patience=6)
]

# %%
hist = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=200,
)
# Out:
# Epoch 1/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6540 - loss: 0.6838 - val_accuracy: 0.5455 - val_loss: 0.6910
# Epoch 2/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6459 - loss: 0.6371 - val_accuracy: 0.5594 - val_loss: 0.6338
# Epoch 3/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6969 - loss: 0.5775 - val_accuracy: 0.6154 - val_loss: 0.5995
# Epoch 4/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6952 - loss: 0.5698 - val_accuracy: 0.6853 - val_loss: 0.5723
# Epoch 5/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7512 - loss: 0.5347 - val_accuracy: 0.7203 - val_loss: 0.5492
# Epoch 6/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7862 - loss: 0.5289 - val_accuracy: 0.7343 - val_loss: 0.5308
# Epoch 7/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8064 - loss: 0.4917 - val_accuracy: 0.7622 - val_loss: 0.5128
# Epoch 8/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8088 - loss: 0.4710 - val_accuracy: 0.7762 - val_loss: 0.5014
# Epoch 9/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8115 - loss: 0.4612 - val_accuracy: 0.7762 - val_loss: 0.4902
# Epoch 10/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8245 - loss: 0.4534 - val_accuracy: 0.7832 - val_loss: 0.4849
# Epoch 11/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8052 - loss: 0.4753 - val_accuracy: 0.7832 - val_loss: 0.4814
# Epoch 12/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8046 - loss: 0.4514 - val_accuracy: 0.7902 - val_loss: 0.4799
# Epoch 13/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8251 - loss: 0.4248 - val_accuracy: 0.7762 - val_loss: 0.4801
# Epoch 14/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8182 - loss: 0.4223 - val_accuracy: 0.7692 - val_loss: 0.4775
# Epoch 15/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8117 - loss: 0.4217 - val_accuracy: 0.7692 - val_loss: 0.4774
# Epoch 16/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8127 - loss: 0.4298 - val_accuracy: 0.7762 - val_loss: 0.4803
# Epoch 17/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8064 - loss: 0.4249 - val_accuracy: 0.7832 - val_loss: 0.4779
# Epoch 18/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8140 - loss: 0.4120 - val_accuracy: 0.7832 - val_loss: 0.4767
# Epoch 19/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8136 - loss: 0.4118 - val_accuracy: 0.7762 - val_loss: 0.4749
# Epoch 20/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8203 - loss: 0.3957 - val_accuracy: 0.7762 - val_loss: 0.4785
# Epoch 21/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8156 - loss: 0.4082 - val_accuracy: 0.7762 - val_loss: 0.4747
# Epoch 22/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8104 - loss: 0.4164 - val_accuracy: 0.7692 - val_loss: 0.4748
# Epoch 23/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8235 - loss: 0.4179 - val_accuracy: 0.7832 - val_loss: 0.4702
# Epoch 24/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8210 - loss: 0.4158 - val_accuracy: 0.7762 - val_loss: 0.4732
# Epoch 25/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8167 - loss: 0.4122 - val_accuracy: 0.7762 - val_loss: 0.4736
# Epoch 26/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8215 - loss: 0.4166 - val_accuracy: 0.7902 - val_loss: 0.4727
# Epoch 27/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8126 - loss: 0.4080 - val_accuracy: 0.7902 - val_loss: 0.4756
# Epoch 28/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8301 - loss: 0.4080 - val_accuracy: 0.7902 - val_loss: 0.4665
# Epoch 29/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8337 - loss: 0.3931 - val_accuracy: 0.7902 - val_loss: 0.4628
# Epoch 30/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8266 - loss: 0.3992 - val_accuracy: 0.7832 - val_loss: 0.4653
# Epoch 31/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8355 - loss: 0.3879 - val_accuracy: 0.7832 - val_loss: 0.4640
# Epoch 32/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8411 - loss: 0.3778 - val_accuracy: 0.7832 - val_loss: 0.4641
# Epoch 33/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8437 - loss: 0.3755 - val_accuracy: 0.7832 - val_loss: 0.4656
# Epoch 34/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8327 - loss: 0.3999 - val_accuracy: 0.7832 - val_loss: 0.4659
# Epoch 35/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8373 - loss: 0.3920 - val_accuracy: 0.7832 - val_loss: 0.4667
# Epoch 36/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8441 - loss: 0.3767 - val_accuracy: 0.7832 - val_loss: 0.4634
# Epoch 37/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8459 - loss: 0.3835 - val_accuracy: 0.7902 - val_loss: 0.4612
# Epoch 38/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8320 - loss: 0.3956 - val_accuracy: 0.7832 - val_loss: 0.4570
# Epoch 39/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8284 - loss: 0.3743 - val_accuracy: 0.7832 - val_loss: 0.4577
# Epoch 40/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8355 - loss: 0.3741 - val_accuracy: 0.7832 - val_loss: 0.4640
# Epoch 41/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8420 - loss: 0.3772 - val_accuracy: 0.7832 - val_loss: 0.4635
# Epoch 42/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8414 - loss: 0.3708 - val_accuracy: 0.7832 - val_loss: 0.4605
# Epoch 43/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8454 - loss: 0.3645 - val_accuracy: 0.7832 - val_loss: 0.4610
# Epoch 44/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8406 - loss: 0.3626 - val_accuracy: 0.7832 - val_loss: 0.4730
# Epoch 45/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8446 - loss: 0.3590 - val_accuracy: 0.7832 - val_loss: 0.4692
# Epoch 46/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8390 - loss: 0.3558 - val_accuracy: 0.7832 - val_loss: 0.4693
# Epoch 47/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8420 - loss: 0.3732 - val_accuracy: 0.7832 - val_loss: 0.4699
# Epoch 48/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8228 - loss: 0.3697 - val_accuracy: 0.7832 - val_loss: 0.4641
# Epoch 49/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8412 - loss: 0.3760 - val_accuracy: 0.7762 - val_loss: 0.4649
# Epoch 50/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8450 - loss: 0.3556 - val_accuracy: 0.7762 - val_loss: 0.4710
# Epoch 51/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8351 - loss: 0.3558 - val_accuracy: 0.7762 - val_loss: 0.4679
# Epoch 52/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8379 - loss: 0.3544 - val_accuracy: 0.7762 - val_loss: 0.4693
# Epoch 53/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8437 - loss: 0.3694 - val_accuracy: 0.7762 - val_loss: 0.4691
# Epoch 54/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8474 - loss: 0.3535 - val_accuracy: 0.7832 - val_loss: 0.4666
# Epoch 55/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8518 - loss: 0.3575 - val_accuracy: 0.7832 - val_loss: 0.4702
# Epoch 56/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8413 - loss: 0.3741 - val_accuracy: 0.7832 - val_loss: 0.4710
# Epoch 57/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8371 - loss: 0.3615 - val_accuracy: 0.7832 - val_loss: 0.4687
# Epoch 58/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8509 - loss: 0.3564 - val_accuracy: 0.7832 - val_loss: 0.4676
# Epoch 59/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8387 - loss: 0.3523 - val_accuracy: 0.7832 - val_loss: 0.4632
# Epoch 60/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8407 - loss: 0.3486 - val_accuracy: 0.7832 - val_loss: 0.4626
# Epoch 61/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8405 - loss: 0.3638 - val_accuracy: 0.7902 - val_loss: 0.4718
# Epoch 62/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8555 - loss: 0.3532 - val_accuracy: 0.7902 - val_loss: 0.4715
# Epoch 63/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8461 - loss: 0.3558 - val_accuracy: 0.7902 - val_loss: 0.4728
# Epoch 64/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8252 - loss: 0.3662 - val_accuracy: 0.7902 - val_loss: 0.4664
# Epoch 65/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8373 - loss: 0.3600 - val_accuracy: 0.7902 - val_loss: 0.4616
# Epoch 66/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8516 - loss: 0.3498 - val_accuracy: 0.7902 - val_loss: 0.4599
# Epoch 67/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8426 - loss: 0.3635 - val_accuracy: 0.7902 - val_loss: 0.4633
# Epoch 68/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8462 - loss: 0.3519 - val_accuracy: 0.7832 - val_loss: 0.4632
# Epoch 69/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8536 - loss: 0.3648 - val_accuracy: 0.7832 - val_loss: 0.4646
# Epoch 70/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8566 - loss: 0.3465 - val_accuracy: 0.7902 - val_loss: 0.4702
# Epoch 71/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8415 - loss: 0.3539 - val_accuracy: 0.7902 - val_loss: 0.4715
# Epoch 72/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8542 - loss: 0.3368 - val_accuracy: 0.7902 - val_loss: 0.4715
# Epoch 73/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8430 - loss: 0.3490 - val_accuracy: 0.7902 - val_loss: 0.4685
# Epoch 74/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8517 - loss: 0.3445 - val_accuracy: 0.7832 - val_loss: 0.4703
# Epoch 75/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8344 - loss: 0.3546 - val_accuracy: 0.7832 - val_loss: 0.4664
# Epoch 76/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8446 - loss: 0.3557 - val_accuracy: 0.7832 - val_loss: 0.4651
# Epoch 77/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8606 - loss: 0.3358 - val_accuracy: 0.7832 - val_loss: 0.4715
# Epoch 78/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8485 - loss: 0.3366 - val_accuracy: 0.7832 - val_loss: 0.4688
# Epoch 79/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8442 - loss: 0.3418 - val_accuracy: 0.7902 - val_loss: 0.4580
# Epoch 80/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8463 - loss: 0.3525 - val_accuracy: 0.7902 - val_loss: 0.4592
# Epoch 81/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8579 - loss: 0.3446 - val_accuracy: 0.7832 - val_loss: 0.4623
# Epoch 82/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8647 - loss: 0.3431 - val_accuracy: 0.7832 - val_loss: 0.4683
# Epoch 83/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8468 - loss: 0.3487 - val_accuracy: 0.7832 - val_loss: 0.4701
# Epoch 84/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8498 - loss: 0.3471 - val_accuracy: 0.7832 - val_loss: 0.4724
# Epoch 85/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8385 - loss: 0.3450 - val_accuracy: 0.7832 - val_loss: 0.4632
# Epoch 86/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8522 - loss: 0.3382 - val_accuracy: 0.7832 - val_loss: 0.4629
# Epoch 87/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8598 - loss: 0.3548 - val_accuracy: 0.7832 - val_loss: 0.4685
# Epoch 88/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8444 - loss: 0.3477 - val_accuracy: 0.7832 - val_loss: 0.4744
# Epoch 89/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8328 - loss: 0.3537 - val_accuracy: 0.7902 - val_loss: 0.4695
# Epoch 90/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8410 - loss: 0.3415 - val_accuracy: 0.7902 - val_loss: 0.4697
# Epoch 91/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8428 - loss: 0.3440 - val_accuracy: 0.7902 - val_loss: 0.4651
# Epoch 92/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8448 - loss: 0.3447 - val_accuracy: 0.7902 - val_loss: 0.4656
# Epoch 93/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8523 - loss: 0.3374 - val_accuracy: 0.7832 - val_loss: 0.4698
# Epoch 94/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8463 - loss: 0.3527 - val_accuracy: 0.7902 - val_loss: 0.4744
# Epoch 95/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8424 - loss: 0.3517 - val_accuracy: 0.7832 - val_loss: 0.4755
# Epoch 96/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8513 - loss: 0.3363 - val_accuracy: 0.7832 - val_loss: 0.4721
# Epoch 97/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8662 - loss: 0.3473 - val_accuracy: 0.7902 - val_loss: 0.4690
# Epoch 98/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8632 - loss: 0.3572 - val_accuracy: 0.7902 - val_loss: 0.4733
# Epoch 99/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8553 - loss: 0.3376 - val_accuracy: 0.7832 - val_loss: 0.4741
# Epoch 100/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8526 - loss: 0.3397 - val_accuracy: 0.7832 - val_loss: 0.4734
# Epoch 101/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8498 - loss: 0.3365 - val_accuracy: 0.7972 - val_loss: 0.4758
# Epoch 102/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8609 - loss: 0.3322 - val_accuracy: 0.7832 - val_loss: 0.4753
# Epoch 103/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8596 - loss: 0.3411 - val_accuracy: 0.7832 - val_loss: 0.4694
# Epoch 104/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8397 - loss: 0.3463 - val_accuracy: 0.7832 - val_loss: 0.4695
# Epoch 105/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8593 - loss: 0.3397 - val_accuracy: 0.7832 - val_loss: 0.4755
# Epoch 106/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8624 - loss: 0.3358 - val_accuracy: 0.7832 - val_loss: 0.4767
# Epoch 107/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8351 - loss: 0.3568 - val_accuracy: 0.7832 - val_loss: 0.4760
# Epoch 108/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8641 - loss: 0.3433 - val_accuracy: 0.7832 - val_loss: 0.4768
# Epoch 109/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8591 - loss: 0.3366 - val_accuracy: 0.8042 - val_loss: 0.4698
# Epoch 110/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8722 - loss: 0.3166 - val_accuracy: 0.7972 - val_loss: 0.4671
# Epoch 111/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8685 - loss: 0.3361 - val_accuracy: 0.7902 - val_loss: 0.4732
# Epoch 112/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8452 - loss: 0.3349 - val_accuracy: 0.7902 - val_loss: 0.4696
# Epoch 113/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8587 - loss: 0.3213 - val_accuracy: 0.7902 - val_loss: 0.4705
# Epoch 114/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8578 - loss: 0.3558 - val_accuracy: 0.7902 - val_loss: 0.4737
# Epoch 115/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8465 - loss: 0.3354 - val_accuracy: 0.7832 - val_loss: 0.4731
# Epoch 116/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8396 - loss: 0.3358 - val_accuracy: 0.7902 - val_loss: 0.4733
# Epoch 117/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8689 - loss: 0.3297 - val_accuracy: 0.7902 - val_loss: 0.4801
# Epoch 118/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8347 - loss: 0.3383 - val_accuracy: 0.7832 - val_loss: 0.4798
# Epoch 119/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8660 - loss: 0.3355 - val_accuracy: 0.7832 - val_loss: 0.4772
# Epoch 120/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8534 - loss: 0.3334 - val_accuracy: 0.7832 - val_loss: 0.4758
# Epoch 121/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8658 - loss: 0.3272 - val_accuracy: 0.7832 - val_loss: 0.4772
# Epoch 122/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8509 - loss: 0.3447 - val_accuracy: 0.7902 - val_loss: 0.4751
# Epoch 123/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8687 - loss: 0.3319 - val_accuracy: 0.7902 - val_loss: 0.4736
# Epoch 124/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8615 - loss: 0.3351 - val_accuracy: 0.7762 - val_loss: 0.4770
# Epoch 125/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8402 - loss: 0.3615 - val_accuracy: 0.7762 - val_loss: 0.4732
# Epoch 126/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8497 - loss: 0.3491 - val_accuracy: 0.7762 - val_loss: 0.4719
# Epoch 127/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8621 - loss: 0.3219 - val_accuracy: 0.7762 - val_loss: 0.4765
# Epoch 128/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8650 - loss: 0.3358 - val_accuracy: 0.7902 - val_loss: 0.4745
# Epoch 129/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8681 - loss: 0.3335 - val_accuracy: 0.7902 - val_loss: 0.4780
# Epoch 130/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8630 - loss: 0.3226 - val_accuracy: 0.7902 - val_loss: 0.4837
# Epoch 131/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8633 - loss: 0.3302 - val_accuracy: 0.7972 - val_loss: 0.4812
# Epoch 132/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8601 - loss: 0.3355 - val_accuracy: 0.7972 - val_loss: 0.4828
# Epoch 133/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8562 - loss: 0.3416 - val_accuracy: 0.7902 - val_loss: 0.4835
# Epoch 134/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8485 - loss: 0.3397 - val_accuracy: 0.7902 - val_loss: 0.4827
# Epoch 135/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8603 - loss: 0.3333 - val_accuracy: 0.7902 - val_loss: 0.4784
# Epoch 136/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8661 - loss: 0.3358 - val_accuracy: 0.7902 - val_loss: 0.4873
# Epoch 137/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8471 - loss: 0.3311 - val_accuracy: 0.7902 - val_loss: 0.4870
# Epoch 138/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8531 - loss: 0.3286 - val_accuracy: 0.7832 - val_loss: 0.4836
# Epoch 139/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8565 - loss: 0.3238 - val_accuracy: 0.7832 - val_loss: 0.4827
# Epoch 140/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8544 - loss: 0.3379 - val_accuracy: 0.7972 - val_loss: 0.4864
# Epoch 141/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8850 - loss: 0.3018 - val_accuracy: 0.7972 - val_loss: 0.4843
# Epoch 142/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8537 - loss: 0.3311 - val_accuracy: 0.7902 - val_loss: 0.4792
# Epoch 143/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8606 - loss: 0.3506 - val_accuracy: 0.7972 - val_loss: 0.4801
# Epoch 144/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8527 - loss: 0.3365 - val_accuracy: 0.7902 - val_loss: 0.4835
# Epoch 145/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8586 - loss: 0.3226 - val_accuracy: 0.7902 - val_loss: 0.4819
# Epoch 146/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8621 - loss: 0.3302 - val_accuracy: 0.7972 - val_loss: 0.4867
# Epoch 147/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8845 - loss: 0.3120 - val_accuracy: 0.7972 - val_loss: 0.4899
# Epoch 148/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8561 - loss: 0.3390 - val_accuracy: 0.7902 - val_loss: 0.4879
# Epoch 149/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8694 - loss: 0.3198 - val_accuracy: 0.7902 - val_loss: 0.4935
# Epoch 150/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8721 - loss: 0.3294 - val_accuracy: 0.7902 - val_loss: 0.4966
# Epoch 151/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8537 - loss: 0.3165 - val_accuracy: 0.7902 - val_loss: 0.4904
# Epoch 152/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8601 - loss: 0.3234 - val_accuracy: 0.7902 - val_loss: 0.4851
# Epoch 153/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8571 - loss: 0.3266 - val_accuracy: 0.7972 - val_loss: 0.4878
# Epoch 154/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8545 - loss: 0.3256 - val_accuracy: 0.7902 - val_loss: 0.4924
# Epoch 155/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8724 - loss: 0.3228 - val_accuracy: 0.7972 - val_loss: 0.4946
# Epoch 156/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8537 - loss: 0.3342 - val_accuracy: 0.7972 - val_loss: 0.4925
# Epoch 157/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8542 - loss: 0.3263 - val_accuracy: 0.7972 - val_loss: 0.4927
# Epoch 158/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8815 - loss: 0.3137 - val_accuracy: 0.7902 - val_loss: 0.4904
# Epoch 159/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8644 - loss: 0.3126 - val_accuracy: 0.7902 - val_loss: 0.4896
# Epoch 160/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8718 - loss: 0.2998 - val_accuracy: 0.7972 - val_loss: 0.4848
# Epoch 161/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8469 - loss: 0.3319 - val_accuracy: 0.7902 - val_loss: 0.4896
# Epoch 162/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8691 - loss: 0.3204 - val_accuracy: 0.7762 - val_loss: 0.5007
# Epoch 163/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8589 - loss: 0.3191 - val_accuracy: 0.7762 - val_loss: 0.5015
# Epoch 164/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8669 - loss: 0.3203 - val_accuracy: 0.7832 - val_loss: 0.5010
# Epoch 165/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8805 - loss: 0.3154 - val_accuracy: 0.7832 - val_loss: 0.4978
# Epoch 166/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8705 - loss: 0.3073 - val_accuracy: 0.7832 - val_loss: 0.4977
# Epoch 167/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8705 - loss: 0.3222 - val_accuracy: 0.7832 - val_loss: 0.5056
# Epoch 168/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8670 - loss: 0.3200 - val_accuracy: 0.8042 - val_loss: 0.5016
# Epoch 169/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8553 - loss: 0.3278 - val_accuracy: 0.8042 - val_loss: 0.4992
# Epoch 170/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8656 - loss: 0.3233 - val_accuracy: 0.8042 - val_loss: 0.4901
# Epoch 171/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8753 - loss: 0.3088 - val_accuracy: 0.8042 - val_loss: 0.4906
# Epoch 172/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8738 - loss: 0.3078 - val_accuracy: 0.8112 - val_loss: 0.4900
# Epoch 173/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8786 - loss: 0.3201 - val_accuracy: 0.8042 - val_loss: 0.5034
# Epoch 174/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8717 - loss: 0.3112 - val_accuracy: 0.8042 - val_loss: 0.5083
# Epoch 175/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8625 - loss: 0.3270 - val_accuracy: 0.8112 - val_loss: 0.5049
# Epoch 176/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8840 - loss: 0.3112 - val_accuracy: 0.8042 - val_loss: 0.4968
# Epoch 177/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8690 - loss: 0.3260 - val_accuracy: 0.8112 - val_loss: 0.4901
# Epoch 178/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8667 - loss: 0.3414 - val_accuracy: 0.7972 - val_loss: 0.4885
# Epoch 179/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8785 - loss: 0.3041 - val_accuracy: 0.8042 - val_loss: 0.4933
# Epoch 180/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8680 - loss: 0.3237 - val_accuracy: 0.7972 - val_loss: 0.4975
# Epoch 181/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8640 - loss: 0.3236 - val_accuracy: 0.7972 - val_loss: 0.4981
# Epoch 182/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8754 - loss: 0.3030 - val_accuracy: 0.8042 - val_loss: 0.4985
# Epoch 183/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8545 - loss: 0.3319 - val_accuracy: 0.8042 - val_loss: 0.5018
# Epoch 184/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8766 - loss: 0.3160 - val_accuracy: 0.8042 - val_loss: 0.5048
# Epoch 185/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8769 - loss: 0.3168 - val_accuracy: 0.8112 - val_loss: 0.5040
# Epoch 186/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8821 - loss: 0.3052 - val_accuracy: 0.8042 - val_loss: 0.4975
# Epoch 187/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8735 - loss: 0.3075 - val_accuracy: 0.7972 - val_loss: 0.4956
# Epoch 188/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8643 - loss: 0.3236 - val_accuracy: 0.7972 - val_loss: 0.4977
# Epoch 189/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8644 - loss: 0.3193 - val_accuracy: 0.8042 - val_loss: 0.4882
# Epoch 190/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8748 - loss: 0.3118 - val_accuracy: 0.8112 - val_loss: 0.4874
# Epoch 191/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8774 - loss: 0.3262 - val_accuracy: 0.7972 - val_loss: 0.4984
# Epoch 192/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8703 - loss: 0.3157 - val_accuracy: 0.7972 - val_loss: 0.5016
# Epoch 193/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8753 - loss: 0.2974 - val_accuracy: 0.7972 - val_loss: 0.4995
# Epoch 194/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8662 - loss: 0.3124 - val_accuracy: 0.7972 - val_loss: 0.4902
# Epoch 195/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8693 - loss: 0.3088 - val_accuracy: 0.7972 - val_loss: 0.4947
# Epoch 196/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8588 - loss: 0.3265 - val_accuracy: 0.7972 - val_loss: 0.4957
# Epoch 197/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8631 - loss: 0.3177 - val_accuracy: 0.7902 - val_loss: 0.4984
# Epoch 198/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8828 - loss: 0.3032 - val_accuracy: 0.7902 - val_loss: 0.5014
# Epoch 199/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8905 - loss: 0.2939 - val_accuracy: 0.7902 - val_loss: 0.5022
# Epoch 200/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8859 - loss: 0.3057 - val_accuracy: 0.7972 - val_loss: 0.5060

# %%
y_proba = model.predict(X_test).ravel()
y_pred = (y_proba >= 0.5).astype(int)

print("\nMatriz de confusion:\n", confusion_matrix(y_test, y_pred))
print("\nReporte de clasificacion:\n", classification_report(y_test, y_pred, digits=4))
print("\nAUC: ", roc_auc_score(y_test, y_proba))

def predict_one(sample: dict) -> float:
  """
  Recibe un diccionario 'crudo' con las llaves esperadas:
  Pclass, Sex, Age, SibSp, Parch, Fare, Embarked
  (FamilySize e IsAlone se calculan internamente).
  Devuelve probabilidad de supervivencia.
  """

  s = pd.DataFrame([sample])

  s["FamilySize"] = s["SibSp"].fillna(0) + s["Parch"].fillna(0) + 1
  s["IsAlone"] = (s["FamilySize"] == 1).astype(int)

  s_proc = preprocess.transform(s[X.columns])
  s_proc = s_proc.astype("float32")
  proba = model.predict(s_proc).item()
  return proba

  sample = {
      "Pclass": 3, #1, 2 o3
      "Sex": "male",#male / female
      "Age": 25,
      "SibSp": 1,
      "Parch": 0,
      "Fare": 7.25,
      "Embarked": "S" #S, C o Q
  }
  proba = predict_one(sample)
  print(f"Probabilidad de supervivencia: {proba:.4f}")
  print("Sobrevive" if proba >= 0.5 else "No sobrevive")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# Matriz de confusion:
#  [[103   7]
#  [ 23  46]]
#
# Reporte de clasificacion:
#                precision    recall  f1-score   support
#
#            0     0.8175    0.9364    0.8729       110
#            1     0.8679    0.6667    0.7541        69
#
#     accuracy                         0.8324       179
#    macro avg     0.8427    0.8015    0.8135       179
# weighted avg     0.8369    0.8324    0.8271       179
#
#
# AUC:  0.8587615283267457
