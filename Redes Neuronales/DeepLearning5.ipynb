# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %%
SEED = 42
os.environ["PYTHONSSHSEED"] = str(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
print("TensorFlow: ", tf.__version__)
# Out:
# TensorFlow:  2.19.0

# %%
dataset = pd.read_csv("Churn_Modelling.csv")
X = dataset.iloc[:, 3:-1].copy()
y = dataset.iloc[:, -1].values
print("Shapes", X.shape, y.shape)
# Out:
# Shapes (10000, 10) (10000,)

# %%
ct = ColumnTransformer(
      transformers=[(("geo_ohe"), OneHotEncoder(handle_unknown="ignore"), [1]),
                    (("gender_ohe"), OneHotEncoder(handle_unknown="ignore"), [2])],
      remainder="passthrough",
)
X_ohe = ct.fit_transform(X)
X_ohe = np.asarray(X_ohe).astype("float32")

# %%
X_train, X_test, y_train, y_test = train_test_split(X_ohe, y, test_size=0.2, random_state=SEED, stratify=y)

sc = StandardScaler(with_mean=False)
X_train = sc.fit_transform(X_train).astype("float32")
X_test = sc.transform(X_test).astype("float32")

# %%
from tensorflow.keras import layers, models, callbacks
def build_model(input_dim):
  model = models.Sequential([
      layers.Dense(16, activation="relu", input_shape=(input_dim,)),
      layers.Dense(16, activation="relu"),
      layers.Dense(1, activation="sigmoid")
  ])
  model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy", tf.keras.metrics.AUC(name="auc")], )
  return model

ann = build_model(input_dim=X_train.shape[1])
ann.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 513 (2.00 KB)
#  Trainable params: 513 (2.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cb = [

    callbacks.EarlyStopping(monitor="val_auc", patience=10, mode="max", restore_best_weights=True),
    callbacks.ModelCheckpoint("best_ann.keras", monitor="val_auc", save_best_only=True, mode="max"),
    callbacks.TensorBoard(log_dir="logs")
]
# Out:
# [<keras.src.callbacks.early_stopping.EarlyStopping at 0x798d0b8cf740>,
#  <keras.src.callbacks.model_checkpoint.ModelCheckpoint at 0x798d0b5f5fd0>,
#  <keras.src.callbacks.tensorboard.TensorBoard at 0x798d0b5f7c80>]

# %%
history = ann.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=cb)
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7908 - auc: 0.5303 - loss: 0.5172 - val_accuracy: 0.8085 - val_auc: 0.7370 - val_loss: 0.4468
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8078 - auc: 0.7445 - loss: 0.4414 - val_accuracy: 0.8180 - val_auc: 0.7654 - val_loss: 0.4277
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8156 - auc: 0.7676 - loss: 0.4244 - val_accuracy: 0.8250 - val_auc: 0.7886 - val_loss: 0.4128
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8272 - auc: 0.7928 - loss: 0.4080 - val_accuracy: 0.8295 - val_auc: 0.8135 - val_loss: 0.3951
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8386 - auc: 0.8155 - loss: 0.3895 - val_accuracy: 0.8370 - val_auc: 0.8327 - val_loss: 0.3781
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8450 - auc: 0.8318 - loss: 0.3736 - val_accuracy: 0.8420 - val_auc: 0.8435 - val_loss: 0.3652
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8544 - auc: 0.8420 - loss: 0.3619 - val_accuracy: 0.8490 - val_auc: 0.8488 - val_loss: 0.3569
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8570 - auc: 0.8471 - loss: 0.3550 - val_accuracy: 0.8520 - val_auc: 0.8516 - val_loss: 0.3518
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8584 - auc: 0.8502 - loss: 0.3509 - val_accuracy: 0.8550 - val_auc: 0.8535 - val_loss: 0.3493
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8597 - auc: 0.8522 - loss: 0.3480 - val_accuracy: 0.8550 - val_auc: 0.8547 - val_loss: 0.3471
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8612 - auc: 0.8537 - loss: 0.3459 - val_accuracy: 0.8545 - val_auc: 0.8560 - val_loss: 0.3455
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.
# Epoch 37/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8667 - auc: 0.8692 - loss: 0.3270 - val_accuracy: 0.8590 - val_auc: 0.8646 - val_loss: 0.3347
# Epoch 38/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8671 - auc: 0.8691 - loss: 0.3267 - val_accuracy: 0.8585 - val_auc: 0.8648 - val_loss: 0.3348
# Epoch 39/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8679 - auc: 0.8693 - loss: 0.3266 - val_accuracy: 0.8595 - val_auc: 0.8645 - val_loss: 0.3347
# Epoch 40/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8678 - auc: 0.8695 - loss: 0.3263 - val_accuracy: 0.8595 - val_auc: 0.8645 - val_loss: 0.3348
# Epoch 41/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8684 - auc: 0.8697 - loss: 0.3262 - val_accuracy: 0.8600 - val_auc: 0.8646 - val_loss: 0.3347
# Epoch 42/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8693 - auc: 0.8698 - loss: 0.3259 - val_accuracy: 0.8590 - val_auc: 0.8644 - val_loss: 0.3348
# Epoch 43/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8685 - auc: 0.8696 - loss: 0.3259 - val_accuracy: 0.8590 - val_auc: 0.8646 - val_loss: 0.3348
# Epoch 44/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8692 - auc: 0.8696 - loss: 0.3258 - val_accuracy: 0.8595 - val_auc: 0.8645 - val_loss: 0.3347
# Epoch 45/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8697 - auc: 0.8699 - loss: 0.3255 - val_accuracy: 0.8605 - val_auc: 0.8646 - val_loss: 0.3346
# Epoch 46/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8689 - auc: 0.8699 - loss: 0.3253 - val_accuracy: 0.8600 - val_auc: 0.8645 - val_loss: 0.3346
# Epoch 47/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8695 - auc: 0.8701 - loss: 0.3252 - val_accuracy: 0.8610 - val_auc: 0.8649 - val_loss: 0.3345
# Epoch 48/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8694 - auc: 0.8700 - loss: 0.3250 - val_accuracy: 0.8620 - val_auc: 0.8651 - val_loss: 0.3343
# Epoch 49/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8697 - auc: 0.8704 - loss: 0.3248 - val_accuracy: 0.8615 - val_auc: 0.8652 - val_loss: 0.3343
# Epoch 50/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8698 - auc: 0.8703 - loss: 0.3247 - val_accuracy: 0.8610 - val_auc: 0.8648 - val_loss: 0.3344
# Epoch 51/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8705 - auc: 0.8707 - loss: 0.3243 - val_accuracy: 0.8610 - val_auc: 0.8647 - val_loss: 0.3346
# Epoch 52/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8710 - auc: 0.8705 - loss: 0.3242 - val_accuracy: 0.8605 - val_auc: 0.8647 - val_loss: 0.3346
# Epoch 53/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8708 - auc: 0.8708 - loss: 0.3239 - val_accuracy: 0.8615 - val_auc: 0.8645 - val_loss: 0.3346
# Epoch 54/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8704 - auc: 0.8708 - loss: 0.3238 - val_accuracy: 0.8620 - val_auc: 0.8647 - val_loss: 0.3346
# Epoch 55/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8707 - auc: 0.8708 - loss: 0.3237 - val_accuracy: 0.8605 - val_auc: 0.8645 - val_loss: 0.3347
# Epoch 56/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8709 - auc: 0.8710 - loss: 0.3236 - val_accuracy: 0.8610 - val_auc: 0.8642 - val_loss: 0.3347
# Epoch 57/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8712 - auc: 0.8710 - loss: 0.3235 - val_accuracy: 0.8590 - val_auc: 0.8641 - val_loss: 0.3351
# Epoch 58/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8713 - auc: 0.8710 - loss: 0.3234 - val_accuracy: 0.8600 - val_auc: 0.8639 - val_loss: 0.3346
# Epoch 59/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8711 - auc: 0.8714 - loss: 0.3233 - val_accuracy: 0.8590 - val_auc: 0.8637 - val_loss: 0.3348

# %%
y_proba = ann.predict(X_test).ravel(
y_pred
)

# %%
loss, accuracy, auc = ann.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test AUC: {auc:.4f}")
# Out:
# Test Loss: 0.3343
# Test Accuracy: 0.8615
# Test AUC: 0.8652
